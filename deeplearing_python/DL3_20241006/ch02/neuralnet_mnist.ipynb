# %% [markdown]
# # 라이브러리 import

# %%
# coding: utf-8
import sys, os, time
print(os.getcwd())
current_dir = os.path.dirname(os.getcwd())
print(current_dir)
os.chdir(current_dir)

import numpy as np
import pickle
from dataset.mnist import load_mnist
from common.functions import sigmoid, softmax

from PIL import Image
import matplotlib.pyplot as plt
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/ml20250203/code/Users/6b022/DL3_20241006/ch02
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/ml20250203/code/Users/6b022/DL3_20241006

# %% [markdown]
# # 신경망 계산

# %% [markdown]
# ## 함수

# %% [markdown]
# ### 인터넷에서 숫자 데이터 다운로드

# %%
def get_data():
    (x_train, t_train), (x_test, t_test) = load_mnist(flatten=True, normalize=True, one_hot_label=False)
    return x_test, t_test

# %% [markdown]
# ### 신경망 가중치값 파일 로딩

# %%
def init_network():
    print(os.getcwd())
    with open("ch02/sample_weight.pkl", 'rb') as f:
        network = pickle.load(f)
    return network

# %% [markdown]
# ### 신경망 출력값 계산

# %%
def predict(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']

    a1 = np.dot(x, W1) +b1
    z1 = sigmoid(a1)
    a2 = np.dot(z1, W2) +b2
    z2 = sigmoid(a2)
    a3 = np.dot(z2, W3) +b3
    z3 = sigmoid(a3)
    y = softmax(a3)

    return y

# %% [markdown]
# ### 이미지 보여주는 함수

# %%
def img_show(img):
    plt.imshow(img, cmap='gray')
    plt.axis('off') # 축숨기기
    plt.show()

# %% [markdown]
# ## 신경망 계산 - 최종

# %%
x, t = get_data()
network = init_network()
accuracy_cnt = 0
for i in range(len(x)):
    # 신경망 출력도 계산
    y = predict(network, x[i])
    p = np.argmax(y) #확률이 가장 높은 원소의 인덱스를 얻음

    # 예측과 정답이 같으면 print
    if p == t[i]:
        print('Predicted num = ', p, 'Original num = ', t[i])
        #time.sleep(0.5)
        accuracy_cnt += 1

    # else:
    #     print('####Wrong####\nPredicted num = ', p, 'Original num = ', t[i])
    #     #time.sleep(0.5)
    #     accuracy_cnt += 1

# 최종 정확도 출력
print("Accuracy: " + str(float(accuracy_cnt) / len(x)))
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/ml20250203/code/Users/6b022/DL3_20241006
# Predicted num =  7 Original num =  7
# Predicted num =  2 Original num =  2
# Predicted num =  1 Original num =  1
# Predicted num =  0 Original num =  0
# Predicted num =  4 Original num =  4
# Predicted num =  1 Original num =  1
# Predicted num =  4 Original num =  4
# Predicted num =  9 Original num =  9
# Predicted num =  9 Original num =  9
# Predicted num =  0 Original num =  0
# Predicted num =  6 Original num =  6
# Predicted num =  9 Original num =  9
# Predicted num =  0 Original num =  0
# Predicted num =  1 Original num =  1
# Predicted num =  5 Original num =  5
# Predicted num =  9 Original num =  9
# Predicted num =  7 Original num =  7
# Predicted num =  3 Original num =  3
# Predicted num =  4 Original num =  4
# Predicted num =  9 Original num =  9
# Predicted num =  6 Original num =  6
# Predicted num =  6 Original num =  6
# Predicted num =  5 Original num =  5
# ...

# %% [markdown]
# ## 잘못된 레이블 출력

# %%
x, t = get_data()
network = init_network()
#accuracy_cnt = 0
for i in range(len(x)):
    # 신경망 출력도 계산
    y = predict(network, x[i])
    p = np.argmax(y) #확률이 가장 높은 원소의 인덱스를 얻음

    # 예측과 정답이 다르면 print
    if p != t[i]:
        print('####Wrong####\nPredicted num = ', p, 'Original num = ', t[i])
        #time.sleep(0.5)
        #accuracy_cnt += 1
        img = x[i]

        print(img.shape)
        img = img.reshape(28, 28) # 형상을 원래이미지 크기로 변형
        print(img.shape)

        img_show(img)

    # else:
    #     print('####Wrong####\nPredicted num = ', p, 'Original num = ', t[i])
    #     #time.sleep(0.5)
    #     accuracy_cnt += 1

# 최종 정확도 출력
#print("Accuracy: " + str(float(accuracy_cnt) / len(x)))
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/ml20250203/code/Users/6b022/DL3_20241006
# ####Wrong####
# Predicted num =  6 Original num =  5
# (784,)
# (28, 28)
# ####Wrong####
# Predicted num =  6 Original num =  4
# (784,)
# (28, 28)
# ####Wrong####
# Predicted num =  2 Original num =  6
# (784,)
# (28, 28)
# ####Wrong####
# Predicted num =  4 Original num =  9
# (784,)
# (28, 28)
# ####Wrong####
# Predicted num =  4 Original num =  7
# (784,)
# (28, 28)
# ####Wrong####
# Predicted num =  9 Original num =  2
# (784,)
# (28, 28)
# ####Wrong####
# Predicted num =  5 Original num =  6
# (784,)
# (28, 28)
# ####Wrong####
# Predicted num =  7 Original num =  8
# (784,)
# (28, 28)
# ####Wrong####
# Predicted num =  8 Original num =  9
# (784,)
# (28, 28)
# ####Wrong####
# Predicted num =  5 Original num =  3
# (784,)
# (28, 28)
# ####Wrong####
# Predicted num =  2 Original num =  4
# (784,)
# (28, 28)
# ####Wrong####
# Predicted num =  0 Original num =  6
# (784,)
# (28, 28)
# ...
