# %%
import os, sys
print(os.getcwd())
current_dir = os.path.dirname(os.getcwd())
print(current_dir)
os.chdir(current_dir)

import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.optimizer import SGD
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/ml20250203/code/Users/6b022/DL3_20241006/ch05
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/ml20250203/code/Users/6b022/DL3_20241006

# %%
# MNiST 데이터 읽기=============
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 재현하기 위해 학습 데이터 수 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# %%
# weight decay(가중치 감쇠) 설정 ==========
# weight_decay_lambda = 0 # wight_decay를 사용하지 않는 경우
weight_decay_lambda = 0.13

# %%
network = MultiLayerNetExtend(
    input_size=784, 
    hidden_size_list=[100, 100, 100, 100], 
    output_size=10,
    # 가중치에 페널티를 부여하는 옵션
    weight_decay_lambda = weight_decay_lambda
)
optimizer = SGD(lr = 0.01)
max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

# %%
iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(5000000000):

    # 미니 배치 획득
    batch_mask = np.random.choice(train_size, batch_size)
    # 선택된 데이터(batch_mask)의 데이터와 레이블(정담)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    # 기울기 계산, 가중치 업데이트
    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break
# Out:
# epoch:0, train acc:0.08, test acc:0.1078
# epoch:1, train acc:0.09333333333333334, test acc:0.118
# epoch:2, train acc:0.12, test acc:0.1367
# epoch:3, train acc:0.16333333333333333, test acc:0.1632
# epoch:4, train acc:0.21333333333333335, test acc:0.1974
# epoch:5, train acc:0.25666666666666665, test acc:0.2303
# epoch:6, train acc:0.31, test acc:0.2651
# epoch:7, train acc:0.34, test acc:0.2856
# epoch:8, train acc:0.37666666666666665, test acc:0.3052
# epoch:9, train acc:0.41333333333333333, test acc:0.3279
# epoch:10, train acc:0.43666666666666665, test acc:0.3465
# epoch:11, train acc:0.4666666666666667, test acc:0.3613
# epoch:12, train acc:0.4666666666666667, test acc:0.3645
# epoch:13, train acc:0.49666666666666665, test acc:0.3746
# epoch:14, train acc:0.5133333333333333, test acc:0.3814
# epoch:15, train acc:0.5066666666666667, test acc:0.3857
# epoch:16, train acc:0.5333333333333333, test acc:0.4093
# epoch:17, train acc:0.54, test acc:0.424
# epoch:18, train acc:0.55, test acc:0.4366
# epoch:19, train acc:0.5866666666666667, test acc:0.4504
# epoch:20, train acc:0.5933333333333334, test acc:0.4583
# epoch:21, train acc:0.5966666666666667, test acc:0.4688
# epoch:22, train acc:0.6, test acc:0.4702
# epoch:23, train acc:0.6066666666666667, test acc:0.4716
# epoch:24, train acc:0.61, test acc:0.4759
# epoch:25, train acc:0.6, test acc:0.484
# epoch:26, train acc:0.6033333333333334, test acc:0.4877
# epoch:27, train acc:0.6066666666666667, test acc:0.4921
# epoch:28, train acc:0.6166666666666667, test acc:0.5058
# epoch:29, train acc:0.6166666666666667, test acc:0.5093
# epoch:30, train acc:0.6166666666666667, test acc:0.5142
# epoch:31, train acc:0.6266666666666667, test acc:0.5193
# epoch:32, train acc:0.6366666666666667, test acc:0.5258
# epoch:33, train acc:0.6366666666666667, test acc:0.5209
# epoch:34, train acc:0.6466666666666666, test acc:0.5291
# epoch:35, train acc:0.64, test acc:0.5326
# epoch:36, train acc:0.6533333333333333, test acc:0.5369
# epoch:37, train acc:0.66, test acc:0.5397
# epoch:38, train acc:0.6633333333333333, test acc:0.5392
# epoch:39, train acc:0.6733333333333333, test acc:0.5397
# epoch:40, train acc:0.6733333333333333, test acc:0.5492
# epoch:41, train acc:0.69, test acc:0.5456
# epoch:42, train acc:0.6866666666666666, test acc:0.5634
# epoch:43, train acc:0.6833333333333333, test acc:0.5668
# epoch:44, train acc:0.6866666666666666, test acc:0.5705
# epoch:45, train acc:0.6866666666666666, test acc:0.5752
# epoch:46, train acc:0.69, test acc:0.5783
# epoch:47, train acc:0.69, test acc:0.5858
# epoch:48, train acc:0.69, test acc:0.5837
# epoch:49, train acc:0.6833333333333333, test acc:0.5816
# epoch:50, train acc:0.69, test acc:0.5858
# epoch:51, train acc:0.7, test acc:0.5923
# epoch:52, train acc:0.7033333333333334, test acc:0.5931
# epoch:53, train acc:0.7, test acc:0.5959
# epoch:54, train acc:0.7, test acc:0.5892
# epoch:55, train acc:0.6866666666666666, test acc:0.59
# epoch:56, train acc:0.71, test acc:0.6011
# epoch:57, train acc:0.7066666666666667, test acc:0.6117
# epoch:58, train acc:0.73, test acc:0.6127
# epoch:59, train acc:0.7366666666666667, test acc:0.6172
# epoch:60, train acc:0.7366666666666667, test acc:0.6174
# epoch:61, train acc:0.7433333333333333, test acc:0.6285
# epoch:62, train acc:0.73, test acc:0.6249
# epoch:63, train acc:0.7366666666666667, test acc:0.6184
# epoch:64, train acc:0.74, test acc:0.6234
# epoch:65, train acc:0.74, test acc:0.626
# epoch:66, train acc:0.7466666666666667, test acc:0.6297
# epoch:67, train acc:0.74, test acc:0.6251
# epoch:68, train acc:0.7233333333333334, test acc:0.6204
# epoch:69, train acc:0.7433333333333333, test acc:0.6325
# epoch:70, train acc:0.7533333333333333, test acc:0.6361
# epoch:71, train acc:0.7566666666666667, test acc:0.6396
# epoch:72, train acc:0.76, test acc:0.6375
# epoch:73, train acc:0.76, test acc:0.6387
# epoch:74, train acc:0.7533333333333333, test acc:0.642
# epoch:75, train acc:0.7366666666666667, test acc:0.6407
# epoch:76, train acc:0.7433333333333333, test acc:0.6458
# epoch:77, train acc:0.7533333333333333, test acc:0.6524
# epoch:78, train acc:0.76, test acc:0.6546
# epoch:79, train acc:0.76, test acc:0.6565
# epoch:80, train acc:0.7633333333333333, test acc:0.656
# epoch:81, train acc:0.75, test acc:0.6542
# epoch:82, train acc:0.7633333333333333, test acc:0.6571
# epoch:83, train acc:0.77, test acc:0.6611
# epoch:84, train acc:0.77, test acc:0.6627
# epoch:85, train acc:0.7666666666666667, test acc:0.6623
# epoch:86, train acc:0.7733333333333333, test acc:0.6621
# epoch:87, train acc:0.7833333333333333, test acc:0.6621
# epoch:88, train acc:0.7833333333333333, test acc:0.6662
# epoch:89, train acc:0.77, test acc:0.6646
# epoch:90, train acc:0.77, test acc:0.6663
# epoch:91, train acc:0.77, test acc:0.6631
# epoch:92, train acc:0.7766666666666666, test acc:0.6633
# epoch:93, train acc:0.7733333333333333, test acc:0.668
# epoch:94, train acc:0.7766666666666666, test acc:0.6741
# epoch:95, train acc:0.7733333333333333, test acc:0.6732
# epoch:96, train acc:0.7766666666666666, test acc:0.671
# epoch:97, train acc:0.78, test acc:0.6731
# epoch:98, train acc:0.7833333333333333, test acc:0.6768
# epoch:99, train acc:0.7966666666666666, test acc:0.6817
# epoch:100, train acc:0.7866666666666666, test acc:0.6781
# epoch:101, train acc:0.7866666666666666, test acc:0.6783
# epoch:102, train acc:0.8, test acc:0.6805
# epoch:103, train acc:0.7933333333333333, test acc:0.6788
# epoch:104, train acc:0.79, test acc:0.6746
# epoch:105, train acc:0.7866666666666666, test acc:0.6788
# epoch:106, train acc:0.7933333333333333, test acc:0.6821
# epoch:107, train acc:0.8, test acc:0.6793
# epoch:108, train acc:0.7933333333333333, test acc:0.6809
# epoch:109, train acc:0.7933333333333333, test acc:0.6872
# epoch:110, train acc:0.8, test acc:0.6846
# epoch:111, train acc:0.8033333333333333, test acc:0.69
# epoch:112, train acc:0.8, test acc:0.6906
# epoch:113, train acc:0.8066666666666666, test acc:0.6909
# epoch:114, train acc:0.8033333333333333, test acc:0.6888
# epoch:115, train acc:0.8, test acc:0.6835
# epoch:116, train acc:0.8, test acc:0.688
# epoch:117, train acc:0.8033333333333333, test acc:0.6904
# epoch:118, train acc:0.8166666666666667, test acc:0.6935
# epoch:119, train acc:0.81, test acc:0.6931
# epoch:120, train acc:0.8166666666666667, test acc:0.6925
# epoch:121, train acc:0.8066666666666666, test acc:0.6873
# epoch:122, train acc:0.8066666666666666, test acc:0.6948
# epoch:123, train acc:0.8066666666666666, test acc:0.6929
# epoch:124, train acc:0.8, test acc:0.6876
# epoch:125, train acc:0.7866666666666666, test acc:0.6839
# epoch:126, train acc:0.8033333333333333, test acc:0.6873
# epoch:127, train acc:0.8, test acc:0.69
# epoch:128, train acc:0.8066666666666666, test acc:0.6888
# epoch:129, train acc:0.8066666666666666, test acc:0.6944
# epoch:130, train acc:0.8, test acc:0.6936
# epoch:131, train acc:0.8, test acc:0.6947
# epoch:132, train acc:0.7966666666666666, test acc:0.6959
# epoch:133, train acc:0.8033333333333333, test acc:0.6932
# epoch:134, train acc:0.82, test acc:0.6938
# epoch:135, train acc:0.8166666666666667, test acc:0.6975
# epoch:136, train acc:0.8233333333333334, test acc:0.6977
# epoch:137, train acc:0.8166666666666667, test acc:0.7018
# epoch:138, train acc:0.83, test acc:0.6998
# epoch:139, train acc:0.8266666666666667, test acc:0.6983
# epoch:140, train acc:0.8233333333333334, test acc:0.7
# epoch:141, train acc:0.81, test acc:0.7076
# epoch:142, train acc:0.8166666666666667, test acc:0.7032
# epoch:143, train acc:0.8166666666666667, test acc:0.7043
# epoch:144, train acc:0.8166666666666667, test acc:0.7021
# epoch:145, train acc:0.8166666666666667, test acc:0.7
# epoch:146, train acc:0.8133333333333334, test acc:0.7031
# epoch:147, train acc:0.8133333333333334, test acc:0.7013
# epoch:148, train acc:0.81, test acc:0.7067
# epoch:149, train acc:0.81, test acc:0.7051
# epoch:150, train acc:0.8133333333333334, test acc:0.7087
# epoch:151, train acc:0.8066666666666666, test acc:0.7009
# epoch:152, train acc:0.8133333333333334, test acc:0.7073
# epoch:153, train acc:0.8133333333333334, test acc:0.702
# epoch:154, train acc:0.8166666666666667, test acc:0.7061
# epoch:155, train acc:0.8166666666666667, test acc:0.7036
# epoch:156, train acc:0.8233333333333334, test acc:0.7052
# epoch:157, train acc:0.8133333333333334, test acc:0.7055
# epoch:158, train acc:0.82, test acc:0.707
# epoch:159, train acc:0.8266666666666667, test acc:0.7078
# epoch:160, train acc:0.8233333333333334, test acc:0.7082
# epoch:161, train acc:0.8266666666666667, test acc:0.7109
# epoch:162, train acc:0.8166666666666667, test acc:0.7047
# epoch:163, train acc:0.81, test acc:0.7062
# epoch:164, train acc:0.8133333333333334, test acc:0.7049
# epoch:165, train acc:0.81, test acc:0.7025
# epoch:166, train acc:0.8133333333333334, test acc:0.705
# epoch:167, train acc:0.82, test acc:0.7023
# epoch:168, train acc:0.82, test acc:0.7042
# epoch:169, train acc:0.82, test acc:0.7055
# epoch:170, train acc:0.8166666666666667, test acc:0.7042
# epoch:171, train acc:0.81, test acc:0.7019
# epoch:172, train acc:0.82, test acc:0.7033
# epoch:173, train acc:0.81, test acc:0.7023
# epoch:174, train acc:0.81, test acc:0.7001
# epoch:175, train acc:0.81, test acc:0.7046
# epoch:176, train acc:0.82, test acc:0.7086
# epoch:177, train acc:0.82, test acc:0.7071
# epoch:178, train acc:0.82, test acc:0.704
# epoch:179, train acc:0.8133333333333334, test acc:0.7038
# epoch:180, train acc:0.8166666666666667, test acc:0.7052
# epoch:181, train acc:0.8133333333333334, test acc:0.7058
# epoch:182, train acc:0.81, test acc:0.705
# epoch:183, train acc:0.8133333333333334, test acc:0.7033
# epoch:184, train acc:0.8133333333333334, test acc:0.7056
# epoch:185, train acc:0.81, test acc:0.7055
# epoch:186, train acc:0.82, test acc:0.7021
# epoch:187, train acc:0.8166666666666667, test acc:0.7047
# epoch:188, train acc:0.81, test acc:0.7
# epoch:189, train acc:0.8133333333333334, test acc:0.7005
# epoch:190, train acc:0.82, test acc:0.7013
# epoch:191, train acc:0.8133333333333334, test acc:0.6996
# epoch:192, train acc:0.81, test acc:0.699
# epoch:193, train acc:0.82, test acc:0.7011
# epoch:194, train acc:0.8066666666666666, test acc:0.698
# epoch:195, train acc:0.8133333333333334, test acc:0.7007
# epoch:196, train acc:0.82, test acc:0.701
# epoch:197, train acc:0.8233333333333334, test acc:0.703
# epoch:198, train acc:0.81, test acc:0.7019
# epoch:199, train acc:0.81, test acc:0.7031
# epoch:200, train acc:0.82, test acc:0.7043

# %%
# 그래프 그리기 ==================
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='o', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
