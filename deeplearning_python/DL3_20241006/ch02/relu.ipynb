# %%
# coding: utf-8

import numpy as np
import matplotlib.pylab as plt

def relu(x):
    # relu 함수: x값과 0 중 큰 값 return
    return np.maximum(0, X)

# -5.0 부터 5.0까지 0.1 간격으로 array 생성
X = np.arange(-5.0, 5.0, 0.1)
Y = relu(X)
plt.plot(X, Y)
plt.ylim(-0.1, 5.5)
plt.show()
